# %%
import nltk
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from nltk.tokenize import TreebankWordTokenizer
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/mungughyeon/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ### 단어 토큰화

# %% [markdown]
# **word_tokenize**
#
# - nltk의 word_tokenize는 문장을 단어 기반으로 토큰화함. 해당 함수는 space와 구두점을 기준으로 토큰화
# - 해당 함수는 won't를 wo / n't로 분리하고있는 것을 볼 수 있음

# %%
# word_toknize

text = "You won't be able to know about natural language perfectly, but you need to master a number of preprocessing skills to perform natural language processing."
word_tokenize(text)
# Out:
# ['You',
#  'wo',
#  "n't",
#  'be',
#  'able',
#  'to',
#  'know',
#  'about',
#  'natural',
#  'language',
#  'perfectly',
#  ',',
#  'but',
#  'you',
#  'need',
#  'to',
#  'master',
#  'a',
#  'number',
#  'of',
#  'preprocessing',
#  'skills',
#  'to',
#  'perform',
#  'natural',
#  'language',
#  'processing',
#  '.']

# %% [markdown]
# **WordPunctTokenizer**
#
# - WordPunctTokenizer는 word_tokenize에 대한 대안으로써 구두점을 별도로 분류하는 특징을 갖고 있기때문에
# - 앞서, 확인했던 word_tokenize와는 달리 won't를 won과 t로 분리

# %%
# WordPunctTokenizer
punct_tokenizer = WordPunctTokenizer() # 토크나이저를 선언
punct_tokenizer.tokenize(text)
# Out:
# ['You',
#  'won',
#  "'",
#  't',
#  'be',
#  'able',
#  'to',
#  'know',
#  'about',
#  'natural',
#  'language',
#  'perfectly',
#  ',',
#  'but',
#  'you',
#  'need',
#  'to',
#  'master',
#  'a',
#  'number',
#  'of',
#  'preprocessing',
#  'skills',
#  'to',
#  'perform',
#  'natural',
#  'language',
#  'processing',
#  '.']

# %% [markdown]
# **TreebankWordTokenizer**
#
# - TreebankWordTokenizer는 가장 표준적인 방법의 토큰화 방법으로 사용되는 tokenizer 이다.
# - 해당 토크나이저는 두가지 규칙을 갖고 있음
#   - 규칙 1. 하이푼으로 구성된 단어는 하나로 유지
#   - 규칙 2. doesn't와 같이 아포스트로피로 '접어'가 함께하는 단어는 분리

# %%
tree_tokenizer = TreebankWordTokenizer() # 토크나이저를 선언
tree_tokenizer.tokenize(text)
# Out:
# ['You',
#  'wo',
#  "n't",
#  'be',
#  'able',
#  'to',
#  'know',
#  'about',
#  'natural',
#  'language',
#  'perfectly',
#  ',',
#  'but',
#  'you',
#  'need',
#  'to',
#  'master',
#  'a',
#  'number',
#  'of',
#  'preprocessing',
#  'skills',
#  'to',
#  'perform',
#  'natural',
#  'language',
#  'processing',
#  '.']

# %% [markdown]
# ### 문장 토큰화
#
# - nltk.sent_tokenize를 사용하면 마침표에 따라 여러 문장들을 문장 단위로 구분할 수 있음
# - sent_tokenize는 단순히 마침표의 유무 만으로 문장의 종결여부를 판단하지는 않음
# - 따라서 단순히 '.' 이 있다고해서 무조건 구분하는 것은 아님

# %%
sentences = "NLP stands for Natural Language Processing. \
It is a branch of artificial intelligence (AI) that focuses on the interaction between computers and human language. \
NLP combines techniques from linguistics, computer science, and machine learning to enable computers to understand, interpret, \
and generate human language in a way that is meaningful and useful."

nltk.sent_tokenize(sentences) # 문장단위로 분리
# Out:
# ['NLP stands for Natural Language Processing.',
#  'It is a branch of artificial intelligence (AI) that focuses on the interaction between computers and human language.',
#  'NLP combines techniques from linguistics, computer science, and machine learning to enable computers to understand, interpret, and generate human language in a way that is meaningful and useful.']

# %%
sentences = "I am actively looking for Ph.D. students. and you are a Ph.D student."
nltk.sent_tokenize(sentences) # 문장단위로 분리
# Out:
# ['I am actively looking for Ph.D. students.', 'and you are a Ph.D student.']

# %% [markdown]
# ### Cleaning
#
# > 코퍼스 내에서 토큰화 작업에 방해가 되거나 의미가 없는 부분의 텍스트, 노이즈를 제거하는 작업이다.
# > 토큰화 전에 정제를 하기도 하지만, 이후에도 여전히 남아있는 노이즈들을 제거하기 위해 지속적으로 수행한다.
# > 이때 노이즈는 특수 문자 같은 아무 의미도 갖지 않는 글자들을 의미하기도 하지만
# > 분석하고자 하는 목적에 맞지 않는 불필요한 단어들을 말함

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords') # nltk 내장 stopword 다운로드

stop=set(stopwords.words('english'))
print(stop)
# Out:
# {'he', 'with', 're', 'of', "aren't", 'same', 'we', 'both', 'shouldn', "hadn't", 'again', 'against', "i'm", 't', "doesn't", "she'd", 'other', 'theirs', "it'd", 'a', 'ourselves', 'is', 'own', 'below', 'once', 'some', 'yours', 'needn', 'o', 'yourselves', "mightn't", "she'll", 'if', 'few', 'so', "they've", 'me', "don't", "you've", 'has', 'itself', 'it', 'these', 'up', 'couldn', 'an', 'ma', 'ain', "i'd", "i've", 'isn', 'but', "shouldn't", 'by', 'does', 'hadn', 'more', 'just', 'are', 'what', 'was', 'while', 'hasn', 'wasn', 'aren', 'haven', 'himself', "mustn't", 'why', 'this', 'have', 'between', "it's", 'on', 'who', 'above', 'ours', 'mightn', 'at', 'been', 'as', "won't", 'any', 'didn', "should've", 'for', 'y', 'no', 'all', "you'd", 'them', 'nor', 'those', 'which', "wasn't", 'myself', 'do', 'am', 'such', 'here', 'their', 'don', 'than', 'having', 'through', "you're", 'each', "they're", 'after', 'under', 'she', "you'll", "didn't", 'shan', 'the', 'where', 'him', 'did', 'over', 'into', 'will', "i'll", "we'd", 'can', "he'll", 'most', 'off', 'doesn', 'further', 's', "they'll", 'now', 'hers', 'her', "shan't", 'to', 'until', 've', "we're", 'wouldn', 'themselves', 'had', "that'll", "she's", 'weren', "we'll", 'were', 'your', 'won', "wouldn't", 'too', 'm', 'll', 'be', 'd', "couldn't", 'its', 'i', "needn't", 'very', 'being', "haven't", "weren't", 'out', 'whom', 'then', "hasn't", "isn't", 'there', 'or', 'when', 'from', 'should', 'mustn', "we've", 'during', 'how', "it'll", 'that', "they'd", 'our', 'about', 'doing', 'they', 'you', 'only', 'his', 'because', 'my', "he'd", 'before', 'in', "he's", 'herself', 'not', 'yourself', 'down', 'and'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mungughyeon/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
sen="I want to go to shopping and a I want to buy some of snack"
tokens = nltk.word_tokenize(sen)

clean_tokens=[]
for tok in tokens:
  if len(tok.lower()) > 1 and (tok.lower() not in stop): # 토큰의 길이가 1 초과이고, stopword에 속하지 않는 경우
    clean_tokens.append(tok) # clean_tokens 리스트에 추가


print("불용어 포함: ",tokens)
print("불용어 미포함: ",clean_tokens)
# Out:
# 불용어 포함:  ['I', 'want', 'to', 'go', 'to', 'shopping', 'and', 'a', 'I', 'want', 'to', 'buy', 'some', 'of', 'snack']
# 불용어 미포함:  ['want', 'go', 'shopping', 'want', 'buy', 'snack']

# %% [markdown]
# ### Normalization
#
# > 의미가 중복되거나 의미론적으로 유사한 단어들을 하나로 통합하거나, 단어의 원형을 찾아 통일해주는 작업을 말한다.
# > 크게 Stemming과 Lemmatization 등이 있음

# %% [markdown]
# **Stemming**
#
# - stem:(식물의) 줄기라는 뜻을 가진 영어단어로, 언어학에서는 stem을 어간이라고 함
# - 어간은 굴절하는 단어에서 변화하지 않는 부분을 의미. 즉, stemming이란 어간 추출을 말한다.
# - 쉽게 말해 형태가 변한 단어로부터 군더더기를 제거하고 그 단어의 원래 모습을 추출하는 것을 말함
# - 예를 들어 going이라는 단어가 있다면 Stemming을 진행할시 go가 되고
# - Computers라는 단어를 Stemming을 진행할 시 Comput 를 추출하는 과정을 Stemming이라고 한다.

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

s = PorterStemmer() # stemmer 선언
text = "This was not the map we found in Billy Bones's chest, but an accurate copy, complete in all things--names and heights and soundings--with the single exception of the red crosses and the written notes."
words = word_tokenize(text)
print(words)
# Out:
# ['This', 'was', 'not', 'the', 'map', 'we', 'found', 'in', 'Billy', 'Bones', "'s", 'chest', ',', 'but', 'an', 'accurate', 'copy', ',', 'complete', 'in', 'all', 'things', '--', 'names', 'and', 'heights', 'and', 'soundings', '--', 'with', 'the', 'single', 'exception', 'of', 'the', 'red', 'crosses', 'and', 'the', 'written', 'notes', '.']

# %%
for i in words:
     print(f'{i} ==> {s.stem(i)}')
# Out:
# This ==> thi
# was ==> wa
# not ==> not
# the ==> the
# map ==> map
# we ==> we
# found ==> found
# in ==> in
# Billy ==> billi
# Bones ==> bone
# 's ==> 's
# chest ==> chest
# , ==> ,
# but ==> but
# an ==> an
# accurate ==> accur
# copy ==> copi
# , ==> ,
# complete ==> complet
# in ==> in
# all ==> all
# things ==> thing
# -- ==> --
# names ==> name
# and ==> and
# heights ==> height
# and ==> and
# soundings ==> sound
# -- ==> --
# with ==> with
# the ==> the
# single ==> singl
# exception ==> except
# of ==> of
# the ==> the
# red ==> red
# crosses ==> cross
# and ==> and
# the ==> the
# written ==> written
# notes ==> note
# . ==> .

# %% [markdown]
# **Lemmatization**
#
# - Lemmatization이란 문장 속에서 다양한 형태로 활용된(inflected) 단어의 표제어(lemma)를 찾는 일을 뜻함
# - 여기서 말하는 표제어란 사전에서 단어의 뜻을 찾을 때 쓰는 기본형이라고 생각하면 됨
# - 즉 Lemmatization은 단어의 원형을 찾아 통일해주는 작업을 말함
# - 예를들어, is를 Lemmatization하면 be가 되고, ate을 Lemmatization하면 eat이 됨

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer() # lemmatizer 선언
words = ['doing', 'has', 'going', 'loves', 'lives', 'flying', 'dies', 'watching', 'started', 'seen']

for i in words:
  lemma = lemmatizer.lemmatize(i, pos='v')
  print(f'{i} ==> {lemma}') # lemmatization되기 이전단어와 이후 단어를 출력
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/mungughyeon/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# doing ==> do
# has ==> have
# going ==> go
# loves ==> love
# lives ==> live
# flying ==> fly
# dies ==> die
# watching ==> watch
# started ==> start
# seen ==> see

# %% [markdown]
# ### Edit Distance
#
# > Edit Distance란 2개의 문자열이 얼만큼 다른가를 거리개념으로 치환해 숫자로 표현한 것이라고 이해할 수 있음
# > Edit Distance에는 삽입, 삭제, 교체로 크게 3가지 연산이 존재

# %%
import nltk
from nltk.metrics import edit_distance

print(edit_distance("CAT","HAT"))
# Out:
# 1

# %% [markdown]
# ### (예제) HTML 크롤링후 단어 빈도수 구하기

# %%
import nltk
import urllib
import re
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
import matplotlib
import matplotlib.pyplot as plt
import random

#nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mungughyeon/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
response = urllib.request.urlopen('http://python.org/') # 웹에 정보를 요청한 후, 돌려받은 응답을 저장하여 ‘응답 객체(HTTPResponse)’를 반환
html = response.read()
clean = BeautifulSoup(html,'html.parser').get_text() # html 코드 정제 진행

tokens = []
for tok in clean.split():
  tokens.append(tok) # tokens 리스트에 토큰들을 추가

stop = set(stopwords.words('english')) # 불용어 선언

clean_tokens = []
for tok in tokens:
  if len(tok.lower()) > 1 and (tok.lower() not in stop): # 길이가 1 초과이며 stop word가 아닌 것만 추출해
    clean_tokens.append(tok) # clean_tokens 리스트에 추가

Freq_dist_nltk = nltk.FreqDist(clean_tokens) # FreqDist 클래스는 문서에 사용된 단어(토큰)의 사용빈도 정보를 담는 클래스
Freq_dist_nltk.plot(30, cumulative=False) # 상위 30개를 시각화. 누적 갯수 표시는 False
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# <Axes: xlabel='Samples', ylabel='Counts'>
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 8 ) missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 0 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 3 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 18 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 6 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 24 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 19 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 17 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 127 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 16 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 1015 (\N{GREEK CAPITAL LETTER SHO}) missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 26 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 23 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 27 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 25 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 22 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 12191 (\N{KANGXI RADICAL BITTER}) missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 14 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 7 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 2 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 1832 (\N{SYRIAC LETTER SADHE}) missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 2015 (\N{NKO LETTER LA}) missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 5 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 21 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 1 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 591 (\N{LATIN SMALL LETTER Y WITH STROKE}) missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 896 (\u0380) missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 1850 (\N{SYRIAC HBASA ABOVE}) missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 20 () missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 907 (\u038b) missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Glyph 847 (\N{COMBINING GRAPHEME JOINER}) missing from current font.
#   func(*args, **kwargs)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8 ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 0 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 3 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 18 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 6 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 19 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 17 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 16 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 1015 (\N{GREEK CAPITAL LETTER SHO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 23 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 27 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 12191 (\N{KANGXI RADICAL BITTER}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 14 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 7 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 2 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 1832 (\N{SYRIAC LETTER SADHE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 2015 (\N{NKO LETTER LA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 5 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 1 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 591 (\N{LATIN SMALL LETTER Y WITH STROKE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 896 (\u0380) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 1850 (\N{SYRIAC HBASA ABOVE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 907 (\u038b) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/mungughyeon/miniforge3/envs/Upstage/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 847 (\N{COMBINING GRAPHEME JOINER}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
